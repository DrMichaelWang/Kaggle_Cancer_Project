# %%
#import the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import re
import seaborn as sns
from nltk.corpus import stopwords 
from nltk.stem.porter import PorterStemmer 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score
from sklearn import svm
from sklearn import preprocessing

# %%
#load the training dataset
training_variants = pd.read_csv('training_variants.csv')
training_text = pd.read_csv('training_text.csv',sep='\|\|', skiprows=1, engine='python',names=["ID","text"])

# %%
#combine the two training datasets together
merged_variants_text = pd.merge(training_variants, training_text, on = ['ID'])

# %%
#group the merged dataset by class and count
text_group_count = merged_variants_text.groupby("Class")['ID'].count()
text_group_count.sort_values(ascending=False, inplace = True)

# %%
# check the class count results
text_group_count
# Out:
# Class
# 7    953
# 4    686
# 1    568
# 2    452
# 6    275
# 5    242
# 3     89
# 9     37
# 8     19
# Name: ID, dtype: int64

# %%
# create a list that contains all the text classfied in Class 1 to 9
class_txt_assembly = []
for clas in range(1,10):
    class_txt= merged_variants_text.loc[merged_variants_text['Class']==clas]['text']
    class_txt_assembly.append(class_txt)

# %%
# define a function to calculate frequency of words to filter keywords
def classCorpus(corpus):
    word_vectorizer = CountVectorizer(ngram_range=(1,1), analyzer='word')
    sparse_matrix = word_vectorizer.fit_transform(corpus)
    frequencies = sum(sparse_matrix).toarray()[0]
    df=pd.DataFrame(frequencies, index=word_vectorizer.get_feature_names(), columns=['frequency'])
    df.sort_values('frequency', ascending = False, inplace = True)
    return df

# %%
# get the result of frequency of words in each class
result=[]
for corpus in class_txt_assembly:
    result.append(classCorpus(corpus))

# %%
# check the result of class 1
result[0][151:200]
# Out:
#                frequency
# growth              3992
# similar             3984
# within              3980
# showed              3963
# wt                  3934
# cancers             3887
# î²                  3857
# increased           3825
# containing          3806
# signaling           3786
# clinical            3769
# genetic             3736
# interaction         3732
# although            3716
# 12                  3682
# 14                  3653
# normal              3579
# indicated           3545
# could               3544
# likely              3506
# acid                3505
# smad2               3486
# there               3466
# further             3450
# either              3431
# significantly       3418
# brca2               3416
# several             3395
# disease             3389
# through             3387
# transfected         3377
# ability             3341
# because             3319
# significant         3318
# known               3317
# dependent           3288
# line                3261
# 50                  3246
# therefore           3245
# vitro               3216
# mutated             3189
# 16                  3180
# effects             3177
# first               3174
# whereas             3165
# kinase              3156
# structural          3147
# 13                  3146
# addition            3141

# %%
# check the result of class 2
result[1][151:200]
# Out:
#                frequency
# gefitinib           3299
# molecular           3298
# resistant           3298
# kras                3296
# 19                  3261
# survival            3240
# inhibition          3232
# control             3174
# mutated             3136
# similar             3117
# expressing          3116
# cancers             3076
# although            3069
# pik3ca              3044
# 21                  3037
# first               3025
# normal              3012
# 17                  3009
# small               2952
# increased           2943
# amplification       2925
# therapy             2915
# treated             2915
# alterations         2913
# within              2890
# based               2880
# wt                  2867
# role                2863
# secondary           2856
# fusions             2843
# positive            2839
# further             2836
# function            2796
# activating          2793
# presence            2778
# amino               2769
# loop                2697
# known               2697
# 16                  2682
# site                2678
# nsclc               2677
# 50                  2649
# could               2641
# progression         2637
# induced             2626
# detected            2624
# those               2616
# there               2588
# proliferation       2580

# %%
# check the result of class 3
result[2][151:200]
# Out:
#              frequency
# showed             515
# reported           513
# because            506
# tested             505
# specific           499
# into               499
# known              493
# deleterious        490
# samples            489
# compared           485
# its                475
# similar            469
# effects            467
# after              465
# thus               460
# indicated          450
# number             450
# cases              449
# expressed          446
# sequencing         445
# anti               445
# mtorc1             442
# vector             441
# exon               435
# disease            435
# there              435
# experiments        433
# point              430
# 13                 429
# defective          429
# homologous         429
# performed          427
# presence           427
# when               421
# studies            417
# loss               416
# interaction        415
# risk               415
# whether            414
# loop               412
# genetic            412
# increased          411
# il                 411
# inhibitor          411
# some               408
# line               408
# catalytic          407
# those              399
# genes              399

# %%
# check the result of class 4
result[3][151:200]
# Out:
#                  frequency
# showed                4666
# 15                    4661
# compared              4657
# expressed             4600
# similar               4578
# signaling             4546
# within                4506
# family                4484
# brct                  4460
# 12                    4426
# number                4426
# ability               4421
# indicated             4415
# including             4397
# related               4375
# nf1                   4374
# whereas               4370
# containing            4363
# either                4357
# thus                  4342
# effects               4310
# when                  4308
# because               4275
# could                 4249
# tsc2                  4220
# disease               4184
# suppressor            4110
# experiments           4092
# breast                4082
# whether               4076
# expressing            4065
# nuclear               4027
# increased             4026
# 30                    4023
# several               3993
# role                  3983
# dependent             3965
# likely                3954
# further               3940
# co                    3929
# transcriptional       3905
# analyzed              3890
# through               3879
# induced               3863
# pathway               3852
# vivo                  3825
# some                  3810
# genetic               3797
# germline              3773

# %%
# check the result of class 5
result[4][151:200]
# Out:
#                frequency
# disease             1504
# transcription       1496
# 14                  1492
# reported            1490
# alk                 1482
# 20                  1481
# lines               1473
# stem                1468
# 13                  1468
# hr                  1451
# controls            1440
# identified          1428
# compared            1426
# 15                  1410
# tested              1406
# classifi            1406
# site                1399
# described           1397
# set                 1375
# several             1361
# loss                1353
# 12                  1351
# research            1334
# could               1308
# effects             1303
# similar             1302
# addition            1291
# residue             1285
# acid                1257
# containing          1246
# raf                 1246
# alleles             1237
# further             1236
# model               1235
# cisplatin           1235
# whereas             1233
# some                1225
# methods             1222
# after               1222
# including           1219
# 11                  1211
# growth              1208
# analyzed            1204
# expressing          1197
# rmce                1181
# therefore           1176
# predicted           1175
# pa                  1175
# ovarian             1166

# %%
# check the result of class 6
result[5][151:200]
# Out:
#                  frequency
# group                 1634
# assays                1620
# significant           1617
# terminal              1615
# predicted             1615
# thus                  1610
# risk                  1607
# inhibitors            1598
# substitutions         1596
# showed                1590
# into                  1551
# specific              1531
# substitution          1529
# resistant             1526
# information           1514
# structural            1507
# growth                1507
# ubiquitin             1499
# some                  1472
# 16                    1469
# mlh1                  1464
# 14                    1463
# lapatinib             1459
# within                1455
# 17                    1443
# against               1442
# 00                    1441
# compared              1430
# receptor              1426
# mice                  1419
# ligase                1399
# could                 1390
# those                 1382
# patient               1379
# 24                    1365
# lines                 1363
# high                  1348
# performed             1345
# 25                    1340
# causality             1333
# 000                   1332
# similar               1328
# through               1321
# models                1311
# control               1307
# further               1301
# conserved             1300
# 100                   1299
# phosphorylation       1298

# %%
# check the result of class 7
result[6][151:200]
# Out:
#                frequency
# pdgfra              8809
# 13                  8804
# primary             8771
# including           8755
# resistant           8647
# 18                  8573
# similar             8559
# cancers             8471
# proliferation       8422
# presence            8377
# sequencing          8339
# treated             8206
# activating          8170
# performed           8086
# 19                  8033
# although            8002
# control             7991
# cyclin              7918
# activated           7889
# induced             7839
# pcr                 7814
# independent         7753
# myc                 7747
# fusion              7697
# mutated             7684
# amplification       7624
# supplementary       7621
# within              7603
# residues            7586
# site                7485
# factor              7463
# 21                  7454
# could               7438
# small               7401
# nsclc               7399
# erk                 7355
# 17                  7308
# role                7299
# kras                7269
# positive            7243
# further             7155
# vitro               7130
# molecular           7117
# first               7032
# progression         7029
# when                7012
# active              6979
# her2                6925
# effect              6917

# %%
# check the result of class 8
result[7][151:200]
# Out:
#                  frequency
# known                  168
# such                   167
# control                167
# 100                    167
# rhoa                   165
# had                    165
# assay                  164
# changes                164
# no                     164
# induced                162
# atrx                   160
# acid                   159
# 2010                   158
# three                  156
# leiomyomas             155
# 20                     155
# although               154
# allele                 153
# 2009                   152
# then                   150
# detected               150
# clinical               148
# increased              147
# k42                    147
# transcriptional        146
# amino                  145
# 11                     145
# role                   142
# aml                    142
# significant            142
# complex                141
# whether                141
# loss                   139
# when                   138
# 2012                   137
# egfr                   137
# mm                     136
# common                 136
# genome                 134
# hotspot                134
# vitro                  133
# sequence               133
# cancers                133
# shp2                   132
# either                 132
# test                   131
# 12                     130
# there                  130
# same                   130

# %%
# check the result of class 9
result[8][151:200]
# Out:
#                 frequency
# disease               373
# significantly         371
# showed                370
# substrate             366
# 2011                  364
# knockdown             361
# bone                  360
# mitochondrial         354
# 12                    351
# prc2                  351
# known                 347
# effects               342
# their                 342
# 2012                  340
# marrow                335
# result                335
# role                  333
# tet2                  333
# then                  333
# similar               332
# cryptic               331
# allele                329
# binding               329
# junctions             328
# transduced            327
# sites                 327
# well                  326
# anti                  324
# differentially        320
# isocitrate            320
# total                 319
# production            319
# either                319
# containing            319
# transfected           318
# changes               318
# high                  317
# cellular              316
# growth                314
# increase              314
# nadph                 313
# factor                311
# spliceosome           310
# first                 310
# three                 310
# ability               308
# normal                307
# sf3b1wt               306
# 2009                  306
